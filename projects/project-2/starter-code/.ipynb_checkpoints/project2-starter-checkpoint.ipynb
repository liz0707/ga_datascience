# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline
# Out:
# C:\Users\elizabeth.xu\AppData\Local\Continuum\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %%
df_raw.tail()
# Out:
#      admit    gre   gpa  prestige
# 395      0  620.0  4.00       2.0
# 396      0  560.0  3.04       3.0
# 397      0  460.0  2.63       2.0
# 398      0  700.0  3.65       2.0
# 399      0  600.0  3.89       3.0

# %% [markdown]
# Answer: 400 Observations, because these tables start counting at 0 (looking at df_raw.head)

# %% [markdown]
# #### Question 2. Create a summary table

# %%
#function
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %%
df_raw['gpa'].plot(kind='box')

# %%
df_raw['gre'].plot(kind='box')

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: Because the range for GRE is much larger than GPA.

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_clean = df_raw.dropna()
df_clean
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %% [markdown]
# Answer: There are now less rows 397 vs. 400 before

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
#boxplot 1
df_clean['gre'].plot(kind='box')

# %%
#boxplot 2 
df_clean['gpa'].plot(kind='box')

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer: The plot shows that GRE has 2 outliers on the lower end with the circles. The plot shows GPA has 1 outlier on the lower end, and there is skewness towards higher GPA values.

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable 

import seaborn as sns
sns.distplot(df_clean['gre'], kde=False)

# %%
sns.distplot(df_clean['gpa'], kde=False)

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: Looking at the histograms, both don't look exactly normal, however GRE seems more symmetric compared to GPA, which skews left.

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer: To normalize the distribution, we can take the log.

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data

cmap = sns.diverging_palette(220, 10, as_cmap =True)

correlations = df_clean[['gre', 'gpa']].corr()
print correlations
print sns.heatmap(correlations, cmap=cmap)
# Out:
#           gre       gpa
# gre  1.000000  0.382408
# gpa  0.382408  1.000000
# Axes(0.125,0.125;0.62x0.755)

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: The correlation for the two variables is 0.382408

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer: To explore the association between grad school admissions rate and prestige of undergraduate schools, we will look at the correlation between grad school admissions acceptance rate and a undergraduate school rankings (prestige).

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: Hypothesis is that the two are positively correlated: The higher the prestige of undergraduate schools, the higher the admissions rate for grad school.

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %%
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %%
df_raw.head(100)
# Out:
#     admit    gre   gpa  prestige
# 0       0  380.0  3.61       3.0
# 1       1  660.0  3.67       3.0
# 2       1  800.0  4.00       1.0
# 3       1  640.0  3.19       4.0
# 4       0  520.0  2.93       4.0
# 5       1  760.0  3.00       2.0
# 6       1  560.0  2.98       1.0
# 7       0  400.0  3.08       2.0
# 8       1  540.0  3.39       3.0
# 9       0  700.0  3.92       2.0
# 10      0  800.0  4.00       4.0
# 11      0  440.0  3.22       1.0
# 12      1  760.0  4.00       1.0
# 13      0  700.0  3.08       2.0
# 14      1  700.0  4.00       1.0
# 15      0  480.0  3.44       3.0
# 16      0  780.0  3.87       4.0
# 17      0  360.0  2.56       3.0
# 18      0  800.0  3.75       2.0
# 19      1  540.0  3.81       1.0
# 20      0  500.0  3.17       3.0
# 21      1  660.0  3.63       2.0
# 22      0  600.0  2.82       4.0
# 23      0  680.0  3.19       4.0
# 24      1  760.0  3.35       2.0
# 25      1  800.0  3.66       1.0
# 26      1  620.0  3.61       1.0
# ...

# %%
#Will fill in missing data with zeros instead of dropping observation. 
#Know that this worked because there are still  400 rows left.
df_raw.fillna(0)
print df_raw
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %%
#GPA is the column that is clearly skewed left
df_clean.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
np.log(df_clean['gpa']).plot(kind='box')

# %% [markdown]
# #### 3. Advanced: Impute missing data

# %%
#As we did in problem #1, filling in missing data as 0
df_raw.fillna(0)
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...
